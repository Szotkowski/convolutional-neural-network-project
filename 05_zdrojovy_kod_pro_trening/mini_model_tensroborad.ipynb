# %%
import json
import os
import shutil

# Paths
TRAIN_IMG_DIR = './dataset/train/'
VALID_IMG_DIR = './dataset/valid/'
VAL_JSON = './dataset/valid/_annotations.coco.json'

# 1. Load the new validation JSON we created
with open(VAL_JSON, 'r') as f:
    val_data = json.load(f)

# 2. Ensure valid directory exists
os.makedirs(VALID_IMG_DIR, exist_ok=True)

# 3. Move the images mentioned in the validation JSON from train to valid
moved_count = 0
for img_entry in val_data['images']:
    file_name = img_entry['file_name']
    src = os.path.join(TRAIN_IMG_DIR, file_name)
    dst = os.path.join(VALID_IMG_DIR, file_name)
    
    if os.path.exists(src):
        shutil.move(src, dst)
        moved_count += 1

print(f"✅ Successfully moved {moved_count} images to the valid folder.")
# Out:
# ✅ Successfully moved 30 images to the valid folder.

# %%
import os
from rfdetr import RFDETRMedium  # or RFDETRBase/Large depending on your needs

def main():
    # 1. Configuration
    DATASET_PATH = "./dataset" # Path to your COCO folder (must have train/ and valid/)
    OUTPUT_PATH = "./output"
    
    # Ensure output directory exists
    os.makedirs(OUTPUT_PATH, exist_ok=True)

    # 2. Initialize Model with 2 Classes
    # Setting use_ema=False makes weights much easier to load later
    model = RFDETRMedium() 

    print("--- Starting Training: 2 Classes (Lightbulb, Sea Shell) ---")
    
    # 3. Training Loop
    # Adjust batch_size and grad_accum_steps so their product is 16
    # Example: batch_size 4 * grad_accum 4 = 16 (Standard for RF-DETR)
    model.train(
        dataset_dir=DATASET_PATH,
        epochs=100,             # Aim for 100, but 50 is enough for CVAT
        batch_size=2,          
        grad_accum_steps=8,     # Effective batch size of 16
        lr=2e-5,                # Conservative learning rate for stability
        output_dir=OUTPUT_PATH,
        early_stopping=False,   # Keep it running to avoid the save-error
        resolution=640
    )

    print(f"--- Training Complete. Weights saved to {OUTPUT_PATH} ---")

if __name__ == "__main__":
    main()
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# --- Starting Training: 2 Classes (Lightbulb, Sea Shell) ---
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir ./output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=2, grad_accum_steps=8, amp=True, lr=2e-05, lr_encoder=0.00015, batch_size=2, weight_decay=0.0001, epochs=100, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-medium.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=4, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='./dataset', square_resize_div_64=True, output_dir='./output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=640, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=36, mask_downsample_ratio=4, tensorboard=True, wandb=False, project=None, run=None, class_names=['lightbulb', 'sea_shell'], run_test=True, segmentation_head=False, distributed=False)
# number of params: 33367236
# [800]
# Loading annotations into memory...
# Done (t=0.01s)
# Creating index...
# index created!
# [800]
# Loading annotations into memory...
# Done (t=0.00s)
# Creating index...
# index created!
# [800]
# Loading annotations into memory...
# Done (t=0.00s)
# Creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  8
# Total batch size:  16
# LENGTH OF DATA LOADER: 10
# fatal: not a git repository (or any of the parent directories): .git
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# Epoch: [0]  [ 0/10]  eta: 0:00:21  lr: 0.000020  class_error: 100.00  loss: 8.4111 (8.4111)  loss_ce: 1.1131 (1.1131)  loss_bbox: 0.2782 (0.2782)  loss_giou: 0.2612 (0.2612)  loss_ce_0: 1.1911 (1.1911)  loss_bbox_0: 0.2375 (0.2375)  loss_giou_0: 0.2226 (0.2226)  loss_ce_1: 1.1453 (1.1453)  loss_bbox_1: 0.3021 (0.3021)  loss_giou_1: 0.2893 (0.2893)  loss_ce_2: 1.1375 (1.1375)  loss_bbox_2: 0.2789 (0.2789)  loss_giou_2: 0.2579 (0.2579)  loss_ce_enc: 1.1638 (1.1638)  loss_bbox_enc: 0.2614 (0.2614)  loss_giou_enc: 0.2710 (0.2710)  loss_ce_unscaled: 1.1131 (1.1131)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.0556 (0.0556)  loss_giou_unscaled: 0.1306 (0.1306)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 1.1911 (1.1911)  loss_bbox_0_unscaled: 0.0475 (0.0475)  loss_giou_0_unscaled: 0.1113 (0.1113)  cardinality_error_0_unscaled: 35.5000 (35.5000)  loss_ce_1_unscaled: 1.1453 (1.1453)  loss_bbox_1_unscaled: 0.0604 (0.0604)  loss_giou_1_unscaled: 0.1447 (0.1447)  cardinality_error_1_unscaled: 58.0000 (58.0000)  loss_ce_2_unscaled: 1.1375 (1.1375)  loss_bbox_2_unscaled: 0.0558 (0.0558)  loss_giou_2_unscaled: 0.1290 (0.1290)  cardinality_error_2_unscaled: 10.0000 (10.0000)  loss_ce_enc_unscaled: 1.1638 (1.1638)  loss_bbox_enc_unscaled: 0.0523 (0.0523)  loss_giou_enc_unscaled: 0.1355 (0.1355)  cardinality_error_enc_unscaled: 98.5000 (98.5000)  time: 2.1416  data: 0.8690  max mem: 2747
# Epoch: [0]  [ 9/10]  eta: 0:00:01  lr: 0.000020  class_error: 50.00  loss: 0.1187 (2.6688)  loss_ce: 0.0179 (0.3800)  loss_bbox: 0.0000 (0.0648)  loss_giou: 0.0000 (0.0744)  loss_ce_0: 0.0193 (0.3988)  loss_bbox_0: 0.0000 (0.0608)  loss_giou_0: 0.0000 (0.0697)  loss_ce_1: 0.0275 (0.3885)  loss_bbox_1: 0.0000 (0.0740)  loss_giou_1: 0.0000 (0.0837)  loss_ce_2: 0.0442 (0.3908)  loss_bbox_2: 0.0000 (0.0636)  loss_giou_2: 0.0000 (0.0738)  loss_ce_enc: 0.0144 (0.3767)  loss_bbox_enc: 0.0000 (0.0803)  loss_giou_enc: 0.0000 (0.0889)  loss_ce_unscaled: 0.0179 (0.3800)  class_error_unscaled: 100.0000 (85.0000)  loss_bbox_unscaled: 0.0000 (0.0130)  loss_giou_unscaled: 0.0000 (0.0372)  cardinality_error_unscaled: 0.0000 (0.5500)  loss_ce_0_unscaled: 0.0193 (0.3988)  loss_bbox_0_unscaled: 0.0000 (0.0122)  loss_giou_0_unscaled: 0.0000 (0.0348)  cardinality_error_0_unscaled: 13.5000 (26.9500)  loss_ce_1_unscaled: 0.0275 (0.3885)  loss_bbox_1_unscaled: 0.0000 (0.0148)  loss_giou_1_unscaled: 0.0000 (0.0419)  cardinality_error_1_unscaled: 58.0000 (80.1000)  loss_ce_2_unscaled: 0.0442 (0.3908)  loss_bbox_2_unscaled: 0.0000 (0.0127)  loss_giou_2_unscaled: 0.0000 (0.0369)  cardinality_error_2_unscaled: 8.0000 (12.3500)  loss_ce_enc_unscaled: 0.0144 (0.3767)  loss_bbox_enc_unscaled: 0.0000 (0.0161)  loss_giou_enc_unscaled: 0.0000 (0.0444)  cardinality_error_enc_unscaled: 280.0000 (432.6000)  time: 1.2370  data: 0.1023  max mem: 3260
# Epoch: [0] Total time: 0:00:12 (1.2442 s / it)
# Averaged stats: lr: 0.000020  class_error: 50.00  loss: 0.1187 (2.6688)  loss_ce: 0.0179 (0.3800)  loss_bbox: 0.0000 (0.0648)  loss_giou: 0.0000 (0.0744)  loss_ce_0: 0.0193 (0.3988)  loss_bbox_0: 0.0000 (0.0608)  loss_giou_0: 0.0000 (0.0697)  loss_ce_1: 0.0275 (0.3885)  loss_bbox_1: 0.0000 (0.0740)  loss_giou_1: 0.0000 (0.0837)  loss_ce_2: 0.0442 (0.3908)  loss_bbox_2: 0.0000 (0.0636)  loss_giou_2: 0.0000 (0.0738)  loss_ce_enc: 0.0144 (0.3767)  loss_bbox_enc: 0.0000 (0.0803)  loss_giou_enc: 0.0000 (0.0889)  loss_ce_unscaled: 0.0179 (0.3800)  class_error_unscaled: 100.0000 (85.0000)  loss_bbox_unscaled: 0.0000 (0.0130)  loss_giou_unscaled: 0.0000 (0.0372)  cardinality_error_unscaled: 0.0000 (0.5500)  loss_ce_0_unscaled: 0.0193 (0.3988)  loss_bbox_0_unscaled: 0.0000 (0.0122)  loss_giou_0_unscaled: 0.0000 (0.0348)  cardinality_error_0_unscaled: 13.5000 (26.9500)  loss_ce_1_unscaled: 0.0275 (0.3885)  loss_bbox_1_unscaled: 0.0000 (0.0148)  loss_giou_1_unscaled: 0.0000 (0.0419)  cardinality_error_1_unscaled: 58.0000 (80.1000)  loss_ce_2_unscaled: 0.0442 (0.3908)  loss_bbox_2_unscaled: 0.0000 (0.0127)  loss_giou_2_unscaled: 0.0000 (0.0369)  cardinality_error_2_unscaled: 8.0000 (12.3500)  loss_ce_enc_unscaled: 0.0144 (0.3767)  loss_bbox_enc_unscaled: 0.0000 (0.0161)  loss_giou_enc_unscaled: 0.0000 (0.0444)  cardinality_error_enc_unscaled: 280.0000 (432.6000)
# Test:  [ 0/15]  eta: 0:00:04  class_error: 51.85  loss: 8.2797 (8.2797)  loss_ce: 1.1797 (1.1797)  loss_bbox: 0.1176 (0.1176)  loss_giou: 0.3447 (0.3447)  loss_ce_0: 1.1875 (1.1875)  loss_bbox_0: 0.1310 (0.1310)  loss_giou_0: 0.3449 (0.3449)  loss_ce_1: 1.1953 (1.1953)  loss_bbox_1: 0.1195 (0.1195)  loss_giou_1: 0.3318 (0.3318)  loss_ce_2: 1.1797 (1.1797)  loss_bbox_2: 0.1183 (0.1183)  loss_giou_2: 0.3442 (0.3442)  loss_ce_enc: 1.1797 (1.1797)  loss_bbox_enc: 0.1284 (0.1284)  loss_giou_enc: 0.3772 (0.3772)  loss_ce_unscaled: 1.1797 (1.1797)  class_error_unscaled: 51.8519 (51.8519)  loss_bbox_unscaled: 0.0235 (0.0235)  loss_giou_unscaled: 0.1724 (0.1724)  cardinality_error_unscaled: 13.5000 (13.5000)  loss_ce_0_unscaled: 1.1875 (1.1875)  loss_bbox_0_unscaled: 0.0262 (0.0262)  loss_giou_0_unscaled: 0.1725 (0.1725)  cardinality_error_0_unscaled: 13.5000 (13.5000)  loss_ce_1_unscaled: 1.1953 (1.1953)  loss_bbox_1_unscaled: 0.0239 (0.0239)  loss_giou_1_unscaled: 0.1659 (0.1659)  cardinality_error_1_unscaled: 12.0000 (12.0000)  loss_ce_2_unscaled: 1.1797 (1.1797)  loss_bbox_2_unscaled: 0.0237 (0.0237)  loss_giou_2_unscaled: 0.1721 (0.1721)  cardinality_error_2_unscaled: 13.5000 (13.5000)  loss_ce_enc_unscaled: 1.1797 (1.1797)  loss_bbox_enc_unscaled: 0.0257 (0.0257)  loss_giou_enc_unscaled: 0.1886 (0.1886)  cardinality_error_enc_unscaled: 13.5000 (13.5000)  time: 0.2934  data: 0.2096  max mem: 3260
# Test:  [10/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0420 (2.2880)  loss_ce: 0.0111 (0.3444)  loss_bbox: 0.0000 (0.0385)  loss_giou: 0.0000 (0.0692)  loss_ce_0: 0.0108 (0.3509)  loss_bbox_0: 0.0000 (0.0421)  loss_giou_0: 0.0000 (0.0720)  loss_ce_1: 0.0082 (0.3507)  loss_bbox_1: 0.0000 (0.0378)  loss_giou_1: 0.0000 (0.0675)  loss_ce_2: 0.0112 (0.3482)  loss_bbox_2: 0.0000 (0.0382)  loss_giou_2: 0.0000 (0.0701)  loss_ce_enc: 0.0042 (0.3348)  loss_bbox_enc: 0.0000 (0.0468)  loss_giou_enc: 0.0000 (0.0768)  loss_ce_unscaled: 0.0111 (0.3444)  class_error_unscaled: 100.0000 (89.9952)  loss_bbox_unscaled: 0.0000 (0.0077)  loss_giou_unscaled: 0.0000 (0.0346)  cardinality_error_unscaled: 0.0000 (2.0909)  loss_ce_0_unscaled: 0.0108 (0.3509)  loss_bbox_0_unscaled: 0.0000 (0.0084)  loss_giou_0_unscaled: 0.0000 (0.0360)  cardinality_error_0_unscaled: 0.5000 (2.4545)  loss_ce_1_unscaled: 0.0082 (0.3507)  loss_bbox_1_unscaled: 0.0000 (0.0076)  loss_giou_1_unscaled: 0.0000 (0.0338)  cardinality_error_1_unscaled: 1.5000 (3.1364)  loss_ce_2_unscaled: 0.0112 (0.3482)  loss_bbox_2_unscaled: 0.0000 (0.0076)  loss_giou_2_unscaled: 0.0000 (0.0350)  cardinality_error_2_unscaled: 0.0000 (2.2273)  loss_ce_enc_unscaled: 0.0042 (0.3348)  loss_bbox_enc_unscaled: 0.0000 (0.0094)  loss_giou_enc_unscaled: 0.0000 (0.0384)  cardinality_error_enc_unscaled: 7.5000 (18.5909)  time: 0.0915  data: 0.0240  max mem: 3260
# Test:  [14/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0420 (1.6876)  loss_ce: 0.0111 (0.2550)  loss_bbox: 0.0000 (0.0282)  loss_giou: 0.0000 (0.0508)  loss_ce_0: 0.0070 (0.2596)  loss_bbox_0: 0.0000 (0.0309)  loss_giou_0: 0.0000 (0.0528)  loss_ce_1: 0.0071 (0.2587)  loss_bbox_1: 0.0000 (0.0277)  loss_giou_1: 0.0000 (0.0495)  loss_ce_2: 0.0112 (0.2578)  loss_bbox_2: 0.0000 (0.0280)  loss_giou_2: 0.0000 (0.0514)  loss_ce_enc: 0.0042 (0.2465)  loss_bbox_enc: 0.0000 (0.0343)  loss_giou_enc: 0.0000 (0.0563)  loss_ce_unscaled: 0.0111 (0.2550)  class_error_unscaled: 100.0000 (92.6631)  loss_bbox_unscaled: 0.0000 (0.0056)  loss_giou_unscaled: 0.0000 (0.0254)  cardinality_error_unscaled: 0.0000 (1.5333)  loss_ce_0_unscaled: 0.0070 (0.2596)  loss_bbox_0_unscaled: 0.0000 (0.0062)  loss_giou_0_unscaled: 0.0000 (0.0264)  cardinality_error_0_unscaled: 0.5000 (1.9667)  loss_ce_1_unscaled: 0.0071 (0.2587)  loss_bbox_1_unscaled: 0.0000 (0.0055)  loss_giou_1_unscaled: 0.0000 (0.0248)  cardinality_error_1_unscaled: 2.0000 (3.2333)  loss_ce_2_unscaled: 0.0112 (0.2578)  loss_bbox_2_unscaled: 0.0000 (0.0056)  loss_giou_2_unscaled: 0.0000 (0.0257)  cardinality_error_2_unscaled: 0.5000 (1.8667)  loss_ce_enc_unscaled: 0.0042 (0.2465)  loss_bbox_enc_unscaled: 0.0000 (0.0069)  loss_giou_enc_unscaled: 0.0000 (0.0282)  cardinality_error_enc_unscaled: 7.5000 (23.9667)  time: 0.0758  data: 0.0188  max mem: 3260
# Test: Total time: 0:00:01 (0.0799 s / it)
# Averaged stats: class_error: 100.00  loss: 0.0420 (1.6876)  loss_ce: 0.0111 (0.2550)  loss_bbox: 0.0000 (0.0282)  loss_giou: 0.0000 (0.0508)  loss_ce_0: 0.0070 (0.2596)  loss_bbox_0: 0.0000 (0.0309)  loss_giou_0: 0.0000 (0.0528)  loss_ce_1: 0.0071 (0.2587)  loss_bbox_1: 0.0000 (0.0277)  loss_giou_1: 0.0000 (0.0495)  loss_ce_2: 0.0112 (0.2578)  loss_bbox_2: 0.0000 (0.0280)  loss_giou_2: 0.0000 (0.0514)  loss_ce_enc: 0.0042 (0.2465)  loss_bbox_enc: 0.0000 (0.0343)  loss_giou_enc: 0.0000 (0.0563)  loss_ce_unscaled: 0.0111 (0.2550)  class_error_unscaled: 100.0000 (92.6631)  loss_bbox_unscaled: 0.0000 (0.0056)  loss_giou_unscaled: 0.0000 (0.0254)  cardinality_error_unscaled: 0.0000 (1.5333)  loss_ce_0_unscaled: 0.0070 (0.2596)  loss_bbox_0_unscaled: 0.0000 (0.0062)  loss_giou_0_unscaled: 0.0000 (0.0264)  cardinality_error_0_unscaled: 0.5000 (1.9667)  loss_ce_1_unscaled: 0.0071 (0.2587)  loss_bbox_1_unscaled: 0.0000 (0.0055)  loss_giou_1_unscaled: 0.0000 (0.0248)  cardinality_error_1_unscaled: 2.0000 (3.2333)  loss_ce_2_unscaled: 0.0112 (0.2578)  loss_bbox_2_unscaled: 0.0000 (0.0056)  loss_giou_2_unscaled: 0.0000 (0.0257)  cardinality_error_2_unscaled: 0.5000 (1.8667)  loss_ce_enc_unscaled: 0.0042 (0.2465)  loss_bbox_enc_unscaled: 0.0000 (0.0069)  loss_giou_enc_unscaled: 0.0000 (0.0282)  cardinality_error_enc_unscaled: 7.5000 (23.9667)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.15939
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.23133
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.17703
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.05455
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.19891
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.12768
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.13382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.44191
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.53138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.60000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.35000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.59845
# Test:  [ 0/15]  eta: 0:00:04  class_error: 51.85  loss: 8.2642 (8.2642)  loss_ce: 1.1797 (1.1797)  loss_bbox: 0.1095 (0.1095)  loss_giou: 0.3483 (0.3483)  loss_ce_0: 1.1953 (1.1953)  loss_bbox_0: 0.1190 (0.1190)  loss_giou_0: 0.3226 (0.3226)  loss_ce_1: 1.1875 (1.1875)  loss_bbox_1: 0.1266 (0.1266)  loss_giou_1: 0.3417 (0.3417)  loss_ce_2: 1.1797 (1.1797)  loss_bbox_2: 0.1163 (0.1163)  loss_giou_2: 0.3518 (0.3518)  loss_ce_enc: 1.1797 (1.1797)  loss_bbox_enc: 0.1286 (0.1286)  loss_giou_enc: 0.3780 (0.3780)  loss_ce_unscaled: 1.1797 (1.1797)  class_error_unscaled: 51.8519 (51.8519)  loss_bbox_unscaled: 0.0219 (0.0219)  loss_giou_unscaled: 0.1742 (0.1742)  cardinality_error_unscaled: 13.5000 (13.5000)  loss_ce_0_unscaled: 1.1953 (1.1953)  loss_bbox_0_unscaled: 0.0238 (0.0238)  loss_giou_0_unscaled: 0.1613 (0.1613)  cardinality_error_0_unscaled: 13.5000 (13.5000)  loss_ce_1_unscaled: 1.1875 (1.1875)  loss_bbox_1_unscaled: 0.0253 (0.0253)  loss_giou_1_unscaled: 0.1708 (0.1708)  cardinality_error_1_unscaled: 11.5000 (11.5000)  loss_ce_2_unscaled: 1.1797 (1.1797)  loss_bbox_2_unscaled: 0.0233 (0.0233)  loss_giou_2_unscaled: 0.1759 (0.1759)  cardinality_error_2_unscaled: 13.0000 (13.0000)  loss_ce_enc_unscaled: 1.1797 (1.1797)  loss_bbox_enc_unscaled: 0.0257 (0.0257)  loss_giou_enc_unscaled: 0.1890 (0.1890)  cardinality_error_enc_unscaled: 13.5000 (13.5000)  time: 0.2871  data: 0.1947  max mem: 3260
# Test:  [10/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0391 (2.2841)  loss_ce: 0.0109 (0.3432)  loss_bbox: 0.0000 (0.0378)  loss_giou: 0.0000 (0.0696)  loss_ce_0: 0.0095 (0.3498)  loss_bbox_0: 0.0000 (0.0404)  loss_giou_0: 0.0000 (0.0694)  loss_ce_1: 0.0080 (0.3481)  loss_bbox_1: 0.0000 (0.0391)  loss_giou_1: 0.0000 (0.0694)  loss_ce_2: 0.0103 (0.3482)  loss_bbox_2: 0.0000 (0.0385)  loss_giou_2: 0.0000 (0.0701)  loss_ce_enc: 0.0042 (0.3361)  loss_bbox_enc: 0.0000 (0.0471)  loss_giou_enc: 0.0000 (0.0771)  loss_ce_unscaled: 0.0109 (0.3432)  class_error_unscaled: 100.0000 (89.9952)  loss_bbox_unscaled: 0.0000 (0.0076)  loss_giou_unscaled: 0.0000 (0.0348)  cardinality_error_unscaled: 0.0000 (2.0909)  loss_ce_0_unscaled: 0.0095 (0.3498)  loss_bbox_0_unscaled: 0.0000 (0.0081)  loss_giou_0_unscaled: 0.0000 (0.0347)  cardinality_error_0_unscaled: 0.5000 (2.5000)  loss_ce_1_unscaled: 0.0080 (0.3481)  loss_bbox_1_unscaled: 0.0000 (0.0078)  loss_giou_1_unscaled: 0.0000 (0.0347)  cardinality_error_1_unscaled: 1.5000 (2.7273)  loss_ce_2_unscaled: 0.0103 (0.3482)  loss_bbox_2_unscaled: 0.0000 (0.0077)  loss_giou_2_unscaled: 0.0000 (0.0351)  cardinality_error_2_unscaled: 0.0000 (2.0455)  loss_ce_enc_unscaled: 0.0042 (0.3361)  loss_bbox_enc_unscaled: 0.0000 (0.0094)  loss_giou_enc_unscaled: 0.0000 (0.0386)  cardinality_error_enc_unscaled: 7.5000 (18.9091)  time: 0.0687  data: 0.0225  max mem: 3260
# Test:  [14/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0391 (1.6843)  loss_ce: 0.0109 (0.2541)  loss_bbox: 0.0000 (0.0277)  loss_giou: 0.0000 (0.0511)  loss_ce_0: 0.0069 (0.2588)  loss_bbox_0: 0.0000 (0.0296)  loss_giou_0: 0.0000 (0.0509)  loss_ce_1: 0.0069 (0.2567)  loss_bbox_1: 0.0000 (0.0286)  loss_giou_1: 0.0000 (0.0509)  loss_ce_2: 0.0105 (0.2577)  loss_bbox_2: 0.0000 (0.0283)  loss_giou_2: 0.0000 (0.0514)  loss_ce_enc: 0.0041 (0.2473)  loss_bbox_enc: 0.0000 (0.0346)  loss_giou_enc: 0.0000 (0.0566)  loss_ce_unscaled: 0.0109 (0.2541)  class_error_unscaled: 100.0000 (92.6631)  loss_bbox_unscaled: 0.0000 (0.0055)  loss_giou_unscaled: 0.0000 (0.0255)  cardinality_error_unscaled: 0.0000 (1.5333)  loss_ce_0_unscaled: 0.0069 (0.2588)  loss_bbox_0_unscaled: 0.0000 (0.0059)  loss_giou_0_unscaled: 0.0000 (0.0255)  cardinality_error_0_unscaled: 0.5000 (2.0667)  loss_ce_1_unscaled: 0.0069 (0.2567)  loss_bbox_1_unscaled: 0.0000 (0.0057)  loss_giou_1_unscaled: 0.0000 (0.0254)  cardinality_error_1_unscaled: 2.0000 (3.1333)  loss_ce_2_unscaled: 0.0105 (0.2577)  loss_bbox_2_unscaled: 0.0000 (0.0057)  loss_giou_2_unscaled: 0.0000 (0.0257)  cardinality_error_2_unscaled: 0.5000 (1.6667)  loss_ce_enc_unscaled: 0.0041 (0.2473)  loss_bbox_enc_unscaled: 0.0000 (0.0069)  loss_giou_enc_unscaled: 0.0000 (0.0283)  cardinality_error_enc_unscaled: 7.5000 (24.4333)  time: 0.0610  data: 0.0177  max mem: 3260
# Test: Total time: 0:00:00 (0.0649 s / it)
# Averaged stats: class_error: 100.00  loss: 0.0391 (1.6843)  loss_ce: 0.0109 (0.2541)  loss_bbox: 0.0000 (0.0277)  loss_giou: 0.0000 (0.0511)  loss_ce_0: 0.0069 (0.2588)  loss_bbox_0: 0.0000 (0.0296)  loss_giou_0: 0.0000 (0.0509)  loss_ce_1: 0.0069 (0.2567)  loss_bbox_1: 0.0000 (0.0286)  loss_giou_1: 0.0000 (0.0509)  loss_ce_2: 0.0105 (0.2577)  loss_bbox_2: 0.0000 (0.0283)  loss_giou_2: 0.0000 (0.0514)  loss_ce_enc: 0.0041 (0.2473)  loss_bbox_enc: 0.0000 (0.0346)  loss_giou_enc: 0.0000 (0.0566)  loss_ce_unscaled: 0.0109 (0.2541)  class_error_unscaled: 100.0000 (92.6631)  loss_bbox_unscaled: 0.0000 (0.0055)  loss_giou_unscaled: 0.0000 (0.0255)  cardinality_error_unscaled: 0.0000 (1.5333)  loss_ce_0_unscaled: 0.0069 (0.2588)  loss_bbox_0_unscaled: 0.0000 (0.0059)  loss_giou_0_unscaled: 0.0000 (0.0255)  cardinality_error_0_unscaled: 0.5000 (2.0667)  loss_ce_1_unscaled: 0.0069 (0.2567)  loss_bbox_1_unscaled: 0.0000 (0.0057)  loss_giou_1_unscaled: 0.0000 (0.0254)  cardinality_error_1_unscaled: 2.0000 (3.1333)  loss_ce_2_unscaled: 0.0105 (0.2577)  loss_bbox_2_unscaled: 0.0000 (0.0057)  loss_giou_2_unscaled: 0.0000 (0.0257)  cardinality_error_2_unscaled: 0.5000 (1.6667)  loss_ce_enc_unscaled: 0.0041 (0.2473)  loss_bbox_enc_unscaled: 0.0000 (0.0069)  loss_giou_enc_unscaled: 0.0000 (0.0283)  cardinality_error_enc_unscaled: 7.5000 (24.4333)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.15066
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.22190
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.17044
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.05000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.20057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.11658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.13197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.41676
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.50097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.60000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.34545
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.56584
# Grad accum steps:  8
# Total batch size:  16
# LENGTH OF DATA LOADER: 10
# Epoch: [1]  [ 0/10]  eta: 0:00:19  lr: 0.000020  class_error: 0.00  loss: 8.3940 (8.3940)  loss_ce: 1.3542 (1.3542)  loss_bbox: 0.1187 (0.1187)  loss_giou: 0.1102 (0.1102)  loss_ce_0: 1.4127 (1.4127)  loss_bbox_0: 0.1298 (0.1298)  loss_giou_0: 0.1255 (0.1255)  loss_ce_1: 1.3598 (1.3598)  loss_bbox_1: 0.1296 (0.1296)  loss_giou_1: 0.1291 (0.1291)  loss_ce_2: 1.3477 (1.3477)  loss_bbox_2: 0.1340 (0.1340)  loss_giou_2: 0.1274 (0.1274)  loss_ce_enc: 1.2798 (1.2798)  loss_bbox_enc: 0.3058 (0.3058)  loss_giou_enc: 0.3297 (0.3297)  loss_ce_unscaled: 1.3542 (1.3542)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0237 (0.0237)  loss_giou_unscaled: 0.0551 (0.0551)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 1.4127 (1.4127)  loss_bbox_0_unscaled: 0.0260 (0.0260)  loss_giou_0_unscaled: 0.0627 (0.0627)  cardinality_error_0_unscaled: 2.5000 (2.5000)  loss_ce_1_unscaled: 1.3598 (1.3598)  loss_bbox_1_unscaled: 0.0259 (0.0259)  loss_giou_1_unscaled: 0.0645 (0.0645)  cardinality_error_1_unscaled: 29.0000 (29.0000)  loss_ce_2_unscaled: 1.3477 (1.3477)  loss_bbox_2_unscaled: 0.0268 (0.0268)  loss_giou_2_unscaled: 0.0637 (0.0637)  cardinality_error_2_unscaled: 2.0000 (2.0000)  loss_ce_enc_unscaled: 1.2798 (1.2798)  loss_bbox_enc_unscaled: 0.0612 (0.0612)  loss_giou_enc_unscaled: 0.1649 (0.1649)  cardinality_error_enc_unscaled: 202.5000 (202.5000)  time: 1.9669  data: 0.7422  max mem: 3260
# Epoch: [1]  [ 9/10]  eta: 0:00:01  lr: 0.000020  class_error: 50.00  loss: 1.9360 (3.8779)  loss_ce: 0.4874 (0.6461)  loss_bbox: 0.0000 (0.0530)  loss_giou: 0.0000 (0.0505)  loss_ce_0: 0.7890 (0.6980)  loss_bbox_0: 0.0000 (0.0616)  loss_giou_0: 0.0000 (0.0571)  loss_ce_1: 0.2685 (0.6030)  loss_bbox_1: 0.0000 (0.0568)  loss_giou_1: 0.0000 (0.0533)  loss_ce_2: 0.4509 (0.6364)  loss_bbox_2: 0.0000 (0.0536)  loss_giou_2: 0.0000 (0.0504)  loss_ce_enc: 0.5646 (0.6088)  loss_bbox_enc: 0.0000 (0.1265)  loss_giou_enc: 0.0000 (0.1229)  loss_ce_unscaled: 0.4874 (0.6461)  class_error_unscaled: 100.0000 (70.0000)  loss_bbox_unscaled: 0.0000 (0.0106)  loss_giou_unscaled: 0.0000 (0.0252)  cardinality_error_unscaled: 0.0000 (0.5500)  loss_ce_0_unscaled: 0.7890 (0.6980)  loss_bbox_0_unscaled: 0.0000 (0.0123)  loss_giou_0_unscaled: 0.0000 (0.0286)  cardinality_error_0_unscaled: 29.0000 (39.4500)  loss_ce_1_unscaled: 0.2685 (0.6030)  loss_bbox_1_unscaled: 0.0000 (0.0114)  loss_giou_1_unscaled: 0.0000 (0.0267)  cardinality_error_1_unscaled: 41.5000 (74.2500)  loss_ce_2_unscaled: 0.4509 (0.6364)  loss_bbox_2_unscaled: 0.0000 (0.0107)  loss_giou_2_unscaled: 0.0000 (0.0252)  cardinality_error_2_unscaled: 10.5000 (25.8000)  loss_ce_enc_unscaled: 0.5646 (0.6088)  loss_bbox_enc_unscaled: 0.0000 (0.0253)  loss_giou_enc_unscaled: 0.0000 (0.0614)  cardinality_error_enc_unscaled: 177.5000 (384.9000)  time: 1.2173  data: 0.0872  max mem: 3348
# Epoch: [1] Total time: 0:00:12 (1.2234 s / it)
# Averaged stats: lr: 0.000020  class_error: 50.00  loss: 1.9360 (3.8779)  loss_ce: 0.4874 (0.6461)  loss_bbox: 0.0000 (0.0530)  loss_giou: 0.0000 (0.0505)  loss_ce_0: 0.7890 (0.6980)  loss_bbox_0: 0.0000 (0.0616)  loss_giou_0: 0.0000 (0.0571)  loss_ce_1: 0.2685 (0.6030)  loss_bbox_1: 0.0000 (0.0568)  loss_giou_1: 0.0000 (0.0533)  loss_ce_2: 0.4509 (0.6364)  loss_bbox_2: 0.0000 (0.0536)  loss_giou_2: 0.0000 (0.0504)  loss_ce_enc: 0.5646 (0.6088)  loss_bbox_enc: 0.0000 (0.1265)  loss_giou_enc: 0.0000 (0.1229)  loss_ce_unscaled: 0.4874 (0.6461)  class_error_unscaled: 100.0000 (70.0000)  loss_bbox_unscaled: 0.0000 (0.0106)  loss_giou_unscaled: 0.0000 (0.0252)  cardinality_error_unscaled: 0.0000 (0.5500)  loss_ce_0_unscaled: 0.7890 (0.6980)  loss_bbox_0_unscaled: 0.0000 (0.0123)  loss_giou_0_unscaled: 0.0000 (0.0286)  cardinality_error_0_unscaled: 29.0000 (39.4500)  loss_ce_1_unscaled: 0.2685 (0.6030)  loss_bbox_1_unscaled: 0.0000 (0.0114)  loss_giou_1_unscaled: 0.0000 (0.0267)  cardinality_error_1_unscaled: 41.5000 (74.2500)  loss_ce_2_unscaled: 0.4509 (0.6364)  loss_bbox_2_unscaled: 0.0000 (0.0107)  loss_giou_2_unscaled: 0.0000 (0.0252)  cardinality_error_2_unscaled: 10.5000 (25.8000)  loss_ce_enc_unscaled: 0.5646 (0.6088)  loss_bbox_enc_unscaled: 0.0000 (0.0253)  loss_giou_enc_unscaled: 0.0000 (0.0614)  cardinality_error_enc_unscaled: 177.5000 (384.9000)
# Test:  [ 0/15]  eta: 0:00:03  class_error: 51.85  loss: 8.3347 (8.3347)  loss_ce: 1.2109 (1.2109)  loss_bbox: 0.1115 (0.1115)  loss_giou: 0.3282 (0.3282)  loss_ce_0: 1.2031 (1.2031)  loss_bbox_0: 0.1106 (0.1106)  loss_giou_0: 0.3380 (0.3380)  loss_ce_1: 1.2344 (1.2344)  loss_bbox_1: 0.1132 (0.1132)  loss_giou_1: 0.3270 (0.3270)  loss_ce_2: 1.2188 (1.2188)  loss_bbox_2: 0.1133 (0.1133)  loss_giou_2: 0.3314 (0.3314)  loss_ce_enc: 1.2188 (1.2188)  loss_bbox_enc: 0.1197 (0.1197)  loss_giou_enc: 0.3559 (0.3559)  loss_ce_unscaled: 1.2109 (1.2109)  class_error_unscaled: 51.8519 (51.8519)  loss_bbox_unscaled: 0.0223 (0.0223)  loss_giou_unscaled: 0.1641 (0.1641)  cardinality_error_unscaled: 13.0000 (13.0000)  loss_ce_0_unscaled: 1.2031 (1.2031)  loss_bbox_0_unscaled: 0.0221 (0.0221)  loss_giou_0_unscaled: 0.1690 (0.1690)  cardinality_error_0_unscaled: 11.0000 (11.0000)  loss_ce_1_unscaled: 1.2344 (1.2344)  loss_bbox_1_unscaled: 0.0226 (0.0226)  loss_giou_1_unscaled: 0.1635 (0.1635)  cardinality_error_1_unscaled: 15.5000 (15.5000)  loss_ce_2_unscaled: 1.2188 (1.2188)  loss_bbox_2_unscaled: 0.0227 (0.0227)  loss_giou_2_unscaled: 0.1657 (0.1657)  cardinality_error_2_unscaled: 8.5000 (8.5000)  loss_ce_enc_unscaled: 1.2188 (1.2188)  loss_bbox_enc_unscaled: 0.0239 (0.0239)  loss_giou_enc_unscaled: 0.1780 (0.1780)  cardinality_error_enc_unscaled: 16.0000 (16.0000)  time: 0.2604  data: 0.2004  max mem: 3348
# Test:  [10/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0043 (2.2845)  loss_ce: 0.0010 (0.3478)  loss_bbox: 0.0000 (0.0404)  loss_giou: 0.0000 (0.0693)  loss_ce_0: 0.0012 (0.3496)  loss_bbox_0: 0.0000 (0.0371)  loss_giou_0: 0.0000 (0.0667)  loss_ce_1: 0.0008 (0.3528)  loss_bbox_1: 0.0000 (0.0394)  loss_giou_1: 0.0000 (0.0666)  loss_ce_2: 0.0008 (0.3494)  loss_bbox_2: 0.0000 (0.0410)  loss_giou_2: 0.0000 (0.0701)  loss_ce_enc: 0.0007 (0.3432)  loss_bbox_enc: 0.0000 (0.0389)  loss_giou_enc: 0.0000 (0.0723)  loss_ce_unscaled: 0.0010 (0.3478)  class_error_unscaled: 100.0000 (89.9952)  loss_bbox_unscaled: 0.0000 (0.0081)  loss_giou_unscaled: 0.0000 (0.0346)  cardinality_error_unscaled: 0.0000 (2.1364)  loss_ce_0_unscaled: 0.0012 (0.3496)  loss_bbox_0_unscaled: 0.0000 (0.0074)  loss_giou_0_unscaled: 0.0000 (0.0333)  cardinality_error_0_unscaled: 3.5000 (6.7273)  loss_ce_1_unscaled: 0.0008 (0.3528)  loss_bbox_1_unscaled: 0.0000 (0.0079)  loss_giou_1_unscaled: 0.0000 (0.0333)  cardinality_error_1_unscaled: 18.5000 (19.5000)  loss_ce_2_unscaled: 0.0008 (0.3494)  loss_bbox_2_unscaled: 0.0000 (0.0082)  loss_giou_2_unscaled: 0.0000 (0.0351)  cardinality_error_2_unscaled: 7.5000 (8.8182)  loss_ce_enc_unscaled: 0.0007 (0.3432)  loss_bbox_enc_unscaled: 0.0000 (0.0078)  loss_giou_enc_unscaled: 0.0000 (0.0362)  cardinality_error_enc_unscaled: 102.5000 (100.2727)  time: 0.0606  data: 0.0247  max mem: 3348
# Test:  [14/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0043 (1.6764)  loss_ce: 0.0009 (0.2552)  loss_bbox: 0.0000 (0.0296)  loss_giou: 0.0000 (0.0508)  loss_ce_0: 0.0010 (0.2566)  loss_bbox_0: 0.0000 (0.0272)  loss_giou_0: 0.0000 (0.0489)  loss_ce_1: 0.0008 (0.2589)  loss_bbox_1: 0.0000 (0.0289)  loss_giou_1: 0.0000 (0.0488)  loss_ce_2: 0.0009 (0.2564)  loss_bbox_2: 0.0000 (0.0301)  loss_giou_2: 0.0000 (0.0514)  loss_ce_enc: 0.0007 (0.2519)  loss_bbox_enc: 0.0000 (0.0285)  loss_giou_enc: 0.0000 (0.0531)  loss_ce_unscaled: 0.0009 (0.2552)  class_error_unscaled: 100.0000 (92.6631)  loss_bbox_unscaled: 0.0000 (0.0059)  loss_giou_unscaled: 0.0000 (0.0254)  cardinality_error_unscaled: 0.0000 (1.7667)  loss_ce_0_unscaled: 0.0010 (0.2566)  loss_bbox_0_unscaled: 0.0000 (0.0054)  loss_giou_0_unscaled: 0.0000 (0.0245)  cardinality_error_0_unscaled: 4.0000 (6.6000)  loss_ce_1_unscaled: 0.0008 (0.2589)  loss_bbox_1_unscaled: 0.0000 (0.0058)  loss_giou_1_unscaled: 0.0000 (0.0244)  cardinality_error_1_unscaled: 18.5000 (19.7667)  loss_ce_2_unscaled: 0.0009 (0.2564)  loss_bbox_2_unscaled: 0.0000 (0.0060)  loss_giou_2_unscaled: 0.0000 (0.0257)  cardinality_error_2_unscaled: 7.5000 (9.4000)  loss_ce_enc_unscaled: 0.0007 (0.2519)  loss_bbox_enc_unscaled: 0.0000 (0.0057)  loss_giou_enc_unscaled: 0.0000 (0.0265)  cardinality_error_enc_unscaled: 103.0000 (108.9000)  time: 0.0532  data: 0.0193  max mem: 3348
# Test: Total time: 0:00:00 (0.0574 s / it)
# Averaged stats: class_error: 100.00  loss: 0.0043 (1.6764)  loss_ce: 0.0009 (0.2552)  loss_bbox: 0.0000 (0.0296)  loss_giou: 0.0000 (0.0508)  loss_ce_0: 0.0010 (0.2566)  loss_bbox_0: 0.0000 (0.0272)  loss_giou_0: 0.0000 (0.0489)  loss_ce_1: 0.0008 (0.2589)  loss_bbox_1: 0.0000 (0.0289)  loss_giou_1: 0.0000 (0.0488)  loss_ce_2: 0.0009 (0.2564)  loss_bbox_2: 0.0000 (0.0301)  loss_giou_2: 0.0000 (0.0514)  loss_ce_enc: 0.0007 (0.2519)  loss_bbox_enc: 0.0000 (0.0285)  loss_giou_enc: 0.0000 (0.0531)  loss_ce_unscaled: 0.0009 (0.2552)  class_error_unscaled: 100.0000 (92.6631)  loss_bbox_unscaled: 0.0000 (0.0059)  loss_giou_unscaled: 0.0000 (0.0254)  cardinality_error_unscaled: 0.0000 (1.7667)  loss_ce_0_unscaled: 0.0010 (0.2566)  loss_bbox_0_unscaled: 0.0000 (0.0054)  loss_giou_0_unscaled: 0.0000 (0.0245)  cardinality_error_0_unscaled: 4.0000 (6.6000)  loss_ce_1_unscaled: 0.0008 (0.2589)  loss_bbox_1_unscaled: 0.0000 (0.0058)  loss_giou_1_unscaled: 0.0000 (0.0244)  cardinality_error_1_unscaled: 18.5000 (19.7667)  loss_ce_2_unscaled: 0.0009 (0.2564)  loss_bbox_2_unscaled: 0.0000 (0.0060)  loss_giou_2_unscaled: 0.0000 (0.0257)  cardinality_error_2_unscaled: 7.5000 (9.4000)  loss_ce_enc_unscaled: 0.0007 (0.2519)  loss_bbox_enc_unscaled: 0.0000 (0.0057)  loss_giou_enc_unscaled: 0.0000 (0.0265)  cardinality_error_enc_unscaled: 103.0000 (108.9000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.11933
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.15552
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.13710
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.00000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.34391
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.12013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.16647
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.60526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.63421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.00000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.51932
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.70528
# Test:  [ 0/15]  eta: 0:00:04  class_error: 51.85  loss: 8.3281 (8.3281)  loss_ce: 1.2109 (1.2109)  loss_bbox: 0.1095 (0.1095)  loss_giou: 0.3344 (0.3344)  loss_ce_0: 1.2109 (1.2109)  loss_bbox_0: 0.1060 (0.1060)  loss_giou_0: 0.3300 (0.3300)  loss_ce_1: 1.2188 (1.2188)  loss_bbox_1: 0.1143 (0.1143)  loss_giou_1: 0.3219 (0.3219)  loss_ce_2: 1.2109 (1.2109)  loss_bbox_2: 0.1148 (0.1148)  loss_giou_2: 0.3415 (0.3415)  loss_ce_enc: 1.2109 (1.2109)  loss_bbox_enc: 0.1213 (0.1213)  loss_giou_enc: 0.3720 (0.3720)  loss_ce_unscaled: 1.2109 (1.2109)  class_error_unscaled: 51.8519 (51.8519)  loss_bbox_unscaled: 0.0219 (0.0219)  loss_giou_unscaled: 0.1672 (0.1672)  cardinality_error_unscaled: 13.5000 (13.5000)  loss_ce_0_unscaled: 1.2109 (1.2109)  loss_bbox_0_unscaled: 0.0212 (0.0212)  loss_giou_0_unscaled: 0.1650 (0.1650)  cardinality_error_0_unscaled: 11.0000 (11.0000)  loss_ce_1_unscaled: 1.2188 (1.2188)  loss_bbox_1_unscaled: 0.0229 (0.0229)  loss_giou_1_unscaled: 0.1610 (0.1610)  cardinality_error_1_unscaled: 14.5000 (14.5000)  loss_ce_2_unscaled: 1.2109 (1.2109)  loss_bbox_2_unscaled: 0.0230 (0.0230)  loss_giou_2_unscaled: 0.1707 (0.1707)  cardinality_error_2_unscaled: 9.5000 (9.5000)  loss_ce_enc_unscaled: 1.2109 (1.2109)  loss_bbox_enc_unscaled: 0.0243 (0.0243)  loss_giou_enc_unscaled: 0.1860 (0.1860)  cardinality_error_enc_unscaled: 14.0000 (14.0000)  time: 0.2879  data: 0.1974  max mem: 3348
# Test:  [10/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0041 (2.2835)  loss_ce: 0.0010 (0.3464)  loss_bbox: 0.0000 (0.0400)  loss_giou: 0.0000 (0.0697)  loss_ce_0: 0.0011 (0.3504)  loss_bbox_0: 0.0000 (0.0368)  loss_giou_0: 0.0000 (0.0663)  loss_ce_1: 0.0009 (0.3514)  loss_bbox_1: 0.0000 (0.0396)  loss_giou_1: 0.0000 (0.0662)  loss_ce_2: 0.0007 (0.3494)  loss_bbox_2: 0.0000 (0.0414)  loss_giou_2: 0.0000 (0.0710)  loss_ce_enc: 0.0008 (0.3425)  loss_bbox_enc: 0.0000 (0.0383)  loss_giou_enc: 0.0000 (0.0740)  loss_ce_unscaled: 0.0010 (0.3464)  class_error_unscaled: 100.0000 (89.9952)  loss_bbox_unscaled: 0.0000 (0.0080)  loss_giou_unscaled: 0.0000 (0.0348)  cardinality_error_unscaled: 0.0000 (2.2273)  loss_ce_0_unscaled: 0.0011 (0.3504)  loss_bbox_0_unscaled: 0.0000 (0.0074)  loss_giou_0_unscaled: 0.0000 (0.0332)  cardinality_error_0_unscaled: 3.5000 (6.9091)  loss_ce_1_unscaled: 0.0009 (0.3514)  loss_bbox_1_unscaled: 0.0000 (0.0079)  loss_giou_1_unscaled: 0.0000 (0.0331)  cardinality_error_1_unscaled: 19.5000 (18.4091)  loss_ce_2_unscaled: 0.0007 (0.3494)  loss_bbox_2_unscaled: 0.0000 (0.0083)  loss_giou_2_unscaled: 0.0000 (0.0355)  cardinality_error_2_unscaled: 4.5000 (8.4545)  loss_ce_enc_unscaled: 0.0008 (0.3425)  loss_bbox_enc_unscaled: 0.0000 (0.0077)  loss_giou_enc_unscaled: 0.0000 (0.0370)  cardinality_error_enc_unscaled: 100.5000 (98.9545)  time: 0.0664  data: 0.0230  max mem: 3348
# Test:  [14/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0041 (1.6758)  loss_ce: 0.0010 (0.2543)  loss_bbox: 0.0000 (0.0293)  loss_giou: 0.0000 (0.0511)  loss_ce_0: 0.0011 (0.2572)  loss_bbox_0: 0.0000 (0.0270)  loss_giou_0: 0.0000 (0.0487)  loss_ce_1: 0.0009 (0.2579)  loss_bbox_1: 0.0000 (0.0290)  loss_giou_1: 0.0000 (0.0485)  loss_ce_2: 0.0009 (0.2565)  loss_bbox_2: 0.0000 (0.0304)  loss_giou_2: 0.0000 (0.0521)  loss_ce_enc: 0.0008 (0.2514)  loss_bbox_enc: 0.0000 (0.0281)  loss_giou_enc: 0.0000 (0.0542)  loss_ce_unscaled: 0.0010 (0.2543)  class_error_unscaled: 100.0000 (92.6631)  loss_bbox_unscaled: 0.0000 (0.0059)  loss_giou_unscaled: 0.0000 (0.0256)  cardinality_error_unscaled: 0.0000 (1.8000)  loss_ce_0_unscaled: 0.0011 (0.2572)  loss_bbox_0_unscaled: 0.0000 (0.0054)  loss_giou_0_unscaled: 0.0000 (0.0243)  cardinality_error_0_unscaled: 4.5000 (6.4667)  loss_ce_1_unscaled: 0.0009 (0.2579)  loss_bbox_1_unscaled: 0.0000 (0.0058)  loss_giou_1_unscaled: 0.0000 (0.0243)  cardinality_error_1_unscaled: 19.5000 (19.1333)  loss_ce_2_unscaled: 0.0009 (0.2565)  loss_bbox_2_unscaled: 0.0000 (0.0061)  loss_giou_2_unscaled: 0.0000 (0.0260)  cardinality_error_2_unscaled: 4.5000 (8.7667)  loss_ce_enc_unscaled: 0.0008 (0.2514)  loss_bbox_enc_unscaled: 0.0000 (0.0056)  loss_giou_enc_unscaled: 0.0000 (0.0271)  cardinality_error_enc_unscaled: 102.0000 (107.5333)  time: 0.0598  data: 0.0181  max mem: 3348
# Test: Total time: 0:00:00 (0.0644 s / it)
# Averaged stats: class_error: 100.00  loss: 0.0041 (1.6758)  loss_ce: 0.0010 (0.2543)  loss_bbox: 0.0000 (0.0293)  loss_giou: 0.0000 (0.0511)  loss_ce_0: 0.0011 (0.2572)  loss_bbox_0: 0.0000 (0.0270)  loss_giou_0: 0.0000 (0.0487)  loss_ce_1: 0.0009 (0.2579)  loss_bbox_1: 0.0000 (0.0290)  loss_giou_1: 0.0000 (0.0485)  loss_ce_2: 0.0009 (0.2565)  loss_bbox_2: 0.0000 (0.0304)  loss_giou_2: 0.0000 (0.0521)  loss_ce_enc: 0.0008 (0.2514)  loss_bbox_enc: 0.0000 (0.0281)  loss_giou_enc: 0.0000 (0.0542)  loss_ce_unscaled: 0.0010 (0.2543)  class_error_unscaled: 100.0000 (92.6631)  loss_bbox_unscaled: 0.0000 (0.0059)  loss_giou_unscaled: 0.0000 (0.0256)  cardinality_error_unscaled: 0.0000 (1.8000)  loss_ce_0_unscaled: 0.0011 (0.2572)  loss_bbox_0_unscaled: 0.0000 (0.0054)  loss_giou_0_unscaled: 0.0000 (0.0243)  cardinality_error_0_unscaled: 4.5000 (6.4667)  loss_ce_1_unscaled: 0.0009 (0.2579)  loss_bbox_1_unscaled: 0.0000 (0.0058)  loss_giou_1_unscaled: 0.0000 (0.0243)  cardinality_error_1_unscaled: 19.5000 (19.1333)  loss_ce_2_unscaled: 0.0009 (0.2565)  loss_bbox_2_unscaled: 0.0000 (0.0061)  loss_giou_2_unscaled: 0.0000 (0.0260)  cardinality_error_2_unscaled: 4.5000 (8.7667)  loss_ce_enc_unscaled: 0.0008 (0.2514)  loss_bbox_enc_unscaled: 0.0000 (0.0056)  loss_giou_enc_unscaled: 0.0000 (0.0271)  cardinality_error_enc_unscaled: 102.0000 (107.5333)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.12274
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.16307
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.13814
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.00000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.33735
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.12268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.16647
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.58684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.63947
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.00000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.52386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.71242
# Grad accum steps:  8
# Total batch size:  16
# LENGTH OF DATA LOADER: 10
# Epoch: [2]  [ 0/10]  eta: 0:00:18  lr: 0.000020  class_error: 100.00  loss: 0.0830 (0.0830)  loss_ce: 0.0239 (0.0239)  loss_bbox: 0.0000 (0.0000)  loss_giou: 0.0000 (0.0000)  loss_ce_0: 0.0068 (0.0068)  loss_bbox_0: 0.0000 (0.0000)  loss_giou_0: 0.0000 (0.0000)  loss_ce_1: 0.0175 (0.0175)  loss_bbox_1: 0.0000 (0.0000)  loss_giou_1: 0.0000 (0.0000)  loss_ce_2: 0.0238 (0.0238)  loss_bbox_2: 0.0000 (0.0000)  loss_giou_2: 0.0000 (0.0000)  loss_ce_enc: 0.0110 (0.0110)  loss_bbox_enc: 0.0000 (0.0000)  loss_giou_enc: 0.0000 (0.0000)  loss_ce_unscaled: 0.0239 (0.0239)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.0000 (0.0000)  loss_giou_unscaled: 0.0000 (0.0000)  cardinality_error_unscaled: 0.0000 (0.0000)  loss_ce_0_unscaled: 0.0068 (0.0068)  loss_bbox_0_unscaled: 0.0000 (0.0000)  loss_giou_0_unscaled: 0.0000 (0.0000)  cardinality_error_0_unscaled: 204.0000 (204.0000)  loss_ce_1_unscaled: 0.0175 (0.0175)  loss_bbox_1_unscaled: 0.0000 (0.0000)  loss_giou_1_unscaled: 0.0000 (0.0000)  cardinality_error_1_unscaled: 81.5000 (81.5000)  loss_ce_2_unscaled: 0.0238 (0.0238)  loss_bbox_2_unscaled: 0.0000 (0.0000)  loss_giou_2_unscaled: 0.0000 (0.0000)  cardinality_error_2_unscaled: 85.0000 (85.0000)  loss_ce_enc_unscaled: 0.0110 (0.0110)  loss_bbox_enc_unscaled: 0.0000 (0.0000)  loss_giou_enc_unscaled: 0.0000 (0.0000)  cardinality_error_enc_unscaled: 517.5000 (517.5000)  time: 1.8952  data: 0.6803  max mem: 3348
# Epoch: [2]  [ 9/10]  eta: 0:00:01  lr: 0.000020  class_error: 50.00  loss: 0.2665 (4.1016)  loss_ce: 0.0587 (0.6480)  loss_bbox: 0.0000 (0.0746)  loss_giou: 0.0000 (0.0831)  loss_ce_0: 0.0523 (0.6741)  loss_bbox_0: 0.0000 (0.0746)  loss_giou_0: 0.0000 (0.0800)  loss_ce_1: 0.0523 (0.6598)  loss_bbox_1: 0.0000 (0.0766)  loss_giou_1: 0.0000 (0.0816)  loss_ce_2: 0.0488 (0.6581)  loss_bbox_2: 0.0000 (0.0782)  loss_giou_2: 0.0000 (0.0822)  loss_ce_enc: 0.0651 (0.6310)  loss_bbox_enc: 0.0000 (0.0936)  loss_giou_enc: 0.0000 (0.1061)  loss_ce_unscaled: 0.0587 (0.6480)  class_error_unscaled: 83.3333 (75.0000)  loss_bbox_unscaled: 0.0000 (0.0149)  loss_giou_unscaled: 0.0000 (0.0416)  cardinality_error_unscaled: 1.5000 (2.0000)  loss_ce_0_unscaled: 0.0523 (0.6741)  loss_bbox_0_unscaled: 0.0000 (0.0149)  loss_giou_0_unscaled: 0.0000 (0.0400)  cardinality_error_0_unscaled: 88.0000 (89.5500)  loss_ce_1_unscaled: 0.0523 (0.6598)  loss_bbox_1_unscaled: 0.0000 (0.0153)  loss_giou_1_unscaled: 0.0000 (0.0408)  cardinality_error_1_unscaled: 81.5000 (144.4500)  loss_ce_2_unscaled: 0.0488 (0.6581)  loss_bbox_2_unscaled: 0.0000 (0.0156)  loss_giou_2_unscaled: 0.0000 (0.0411)  cardinality_error_2_unscaled: 70.5000 (73.4000)  loss_ce_enc_unscaled: 0.0651 (0.6310)  loss_bbox_enc_unscaled: 0.0000 (0.0187)  loss_giou_enc_unscaled: 0.0000 (0.0531)  cardinality_error_enc_unscaled: 466.0000 (421.8500)  time: 1.2179  data: 0.0824  max mem: 3348
# Epoch: [2] Total time: 0:00:12 (1.2245 s / it)
# Averaged stats: lr: 0.000020  class_error: 50.00  loss: 0.2665 (4.1016)  loss_ce: 0.0587 (0.6480)  loss_bbox: 0.0000 (0.0746)  loss_giou: 0.0000 (0.0831)  loss_ce_0: 0.0523 (0.6741)  loss_bbox_0: 0.0000 (0.0746)  loss_giou_0: 0.0000 (0.0800)  loss_ce_1: 0.0523 (0.6598)  loss_bbox_1: 0.0000 (0.0766)  loss_giou_1: 0.0000 (0.0816)  loss_ce_2: 0.0488 (0.6581)  loss_bbox_2: 0.0000 (0.0782)  loss_giou_2: 0.0000 (0.0822)  loss_ce_enc: 0.0651 (0.6310)  loss_bbox_enc: 0.0000 (0.0936)  loss_giou_enc: 0.0000 (0.1061)  loss_ce_unscaled: 0.0587 (0.6480)  class_error_unscaled: 83.3333 (75.0000)  loss_bbox_unscaled: 0.0000 (0.0149)  loss_giou_unscaled: 0.0000 (0.0416)  cardinality_error_unscaled: 1.5000 (2.0000)  loss_ce_0_unscaled: 0.0523 (0.6741)  loss_bbox_0_unscaled: 0.0000 (0.0149)  loss_giou_0_unscaled: 0.0000 (0.0400)  cardinality_error_0_unscaled: 88.0000 (89.5500)  loss_ce_1_unscaled: 0.0523 (0.6598)  loss_bbox_1_unscaled: 0.0000 (0.0153)  loss_giou_1_unscaled: 0.0000 (0.0408)  cardinality_error_1_unscaled: 81.5000 (144.4500)  loss_ce_2_unscaled: 0.0488 (0.6581)  loss_bbox_2_unscaled: 0.0000 (0.0156)  loss_giou_2_unscaled: 0.0000 (0.0411)  cardinality_error_2_unscaled: 70.5000 (73.4000)  loss_ce_enc_unscaled: 0.0651 (0.6310)  loss_bbox_enc_unscaled: 0.0000 (0.0187)  loss_giou_enc_unscaled: 0.0000 (0.0531)  cardinality_error_enc_unscaled: 466.0000 (421.8500)
# Test:  [ 0/15]  eta: 0:00:04  class_error: 48.15  loss: 8.3515 (8.3515)  loss_ce: 1.2422 (1.2422)  loss_bbox: 0.1035 (0.1035)  loss_giou: 0.3170 (0.3170)  loss_ce_0: 1.2344 (1.2344)  loss_bbox_0: 0.1035 (0.1035)  loss_giou_0: 0.3172 (0.3172)  loss_ce_1: 1.2500 (1.2500)  loss_bbox_1: 0.1026 (0.1026)  loss_giou_1: 0.3093 (0.3093)  loss_ce_2: 1.2422 (1.2422)  loss_bbox_2: 0.1055 (0.1055)  loss_giou_2: 0.3196 (0.3196)  loss_ce_enc: 1.2188 (1.2188)  loss_bbox_enc: 0.1326 (0.1326)  loss_giou_enc: 0.3533 (0.3533)  loss_ce_unscaled: 1.2422 (1.2422)  class_error_unscaled: 48.1481 (48.1481)  loss_bbox_unscaled: 0.0207 (0.0207)  loss_giou_unscaled: 0.1585 (0.1585)  cardinality_error_unscaled: 13.0000 (13.0000)  loss_ce_0_unscaled: 1.2344 (1.2344)  loss_bbox_0_unscaled: 0.0207 (0.0207)  loss_giou_0_unscaled: 0.1586 (0.1586)  cardinality_error_0_unscaled: 12.5000 (12.5000)  loss_ce_1_unscaled: 1.2500 (1.2500)  loss_bbox_1_unscaled: 0.0205 (0.0205)  loss_giou_1_unscaled: 0.1547 (0.1547)  cardinality_error_1_unscaled: 18.5000 (18.5000)  loss_ce_2_unscaled: 1.2422 (1.2422)  loss_bbox_2_unscaled: 0.0211 (0.0211)  loss_giou_2_unscaled: 0.1598 (0.1598)  cardinality_error_2_unscaled: 10.5000 (10.5000)  loss_ce_enc_unscaled: 1.2188 (1.2188)  loss_bbox_enc_unscaled: 0.0265 (0.0265)  loss_giou_enc_unscaled: 0.1766 (0.1766)  cardinality_error_enc_unscaled: 23.0000 (23.0000)  time: 0.2862  data: 0.2235  max mem: 3348
# Test:  [10/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0308 (2.4170)  loss_ce: 0.0054 (0.3737)  loss_bbox: 0.0000 (0.0378)  loss_giou: 0.0000 (0.0673)  loss_ce_0: 0.0081 (0.3888)  loss_bbox_0: 0.0000 (0.0351)  loss_giou_0: 0.0000 (0.0633)  loss_ce_1: 0.0062 (0.3838)  loss_bbox_1: 0.0000 (0.0350)  loss_giou_1: 0.0000 (0.0631)  loss_ce_2: 0.0039 (0.3736)  loss_bbox_2: 0.0000 (0.0376)  loss_giou_2: 0.0000 (0.0658)  loss_ce_enc: 0.0109 (0.3615)  loss_bbox_enc: 0.0000 (0.0516)  loss_giou_enc: 0.0000 (0.0789)  loss_ce_unscaled: 0.0054 (0.3737)  class_error_unscaled: 100.0000 (88.9009)  loss_bbox_unscaled: 0.0000 (0.0076)  loss_giou_unscaled: 0.0000 (0.0337)  cardinality_error_unscaled: 0.0000 (2.0455)  loss_ce_0_unscaled: 0.0081 (0.3888)  loss_bbox_0_unscaled: 0.0000 (0.0070)  loss_giou_0_unscaled: 0.0000 (0.0317)  cardinality_error_0_unscaled: 3.0000 (5.5000)  loss_ce_1_unscaled: 0.0062 (0.3838)  loss_bbox_1_unscaled: 0.0000 (0.0070)  loss_giou_1_unscaled: 0.0000 (0.0315)  cardinality_error_1_unscaled: 18.0000 (15.5000)  loss_ce_2_unscaled: 0.0039 (0.3736)  loss_bbox_2_unscaled: 0.0000 (0.0075)  loss_giou_2_unscaled: 0.0000 (0.0329)  cardinality_error_2_unscaled: 4.5000 (5.8182)  loss_ce_enc_unscaled: 0.0109 (0.3615)  loss_bbox_enc_unscaled: 0.0000 (0.0103)  loss_giou_enc_unscaled: 0.0000 (0.0395)  cardinality_error_enc_unscaled: 73.0000 (66.6818)  time: 0.0669  data: 0.0287  max mem: 3348
# ...
# Test:  [14/15]  eta: 0:00:00  class_error: 100.00  loss: 0.0268 (3.8050)  loss_ce: 0.0055 (0.8019)  loss_bbox: 0.0000 (0.0284)  loss_giou: 0.0000 (0.0492)  loss_ce_0: 0.0036 (0.5395)  loss_bbox_0: 0.0000 (0.0257)  loss_giou_0: 0.0000 (0.0453)  loss_ce_1: 0.0060 (0.7248)  loss_bbox_1: 0.0000 (0.0267)  loss_giou_1: 0.0000 (0.0460)  loss_ce_2: 0.0056 (0.7940)  loss_bbox_2: 0.0000 (0.0283)  loss_giou_2: 0.0000 (0.0494)  loss_ce_enc: 0.0009 (0.5599)  loss_bbox_enc: 0.0000 (0.0318)  loss_giou_enc: 0.0000 (0.0540)  loss_ce_unscaled: 0.0055 (0.8019)  class_error_unscaled: 100.0000 (83.6684)  loss_bbox_unscaled: 0.0000 (0.0057)  loss_giou_unscaled: 0.0000 (0.0246)  cardinality_error_unscaled: 115.5000 (122.2000)  loss_ce_0_unscaled: 0.0036 (0.5395)  loss_bbox_0_unscaled: 0.0000 (0.0051)  loss_giou_0_unscaled: 0.0000 (0.0227)  cardinality_error_0_unscaled: 198.0000 (203.2333)  loss_ce_1_unscaled: 0.0060 (0.7248)  loss_bbox_1_unscaled: 0.0000 (0.0053)  loss_giou_1_unscaled: 0.0000 (0.0230)  cardinality_error_1_unscaled: 227.0000 (224.4000)  loss_ce_2_unscaled: 0.0056 (0.7940)  loss_bbox_2_unscaled: 0.0000 (0.0057)  loss_giou_2_unscaled: 0.0000 (0.0247)  cardinality_error_2_unscaled: 183.0000 (182.6667)  loss_ce_enc_unscaled: 0.0009 (0.5599)  loss_bbox_enc_unscaled: 0.0000 (0.0064)  loss_giou_enc_unscaled: 0.0000 (0.0270)  cardinality_error_enc_unscaled: 278.0000 (272.6000)  time: 0.0753  data: 0.0263  max mem: 3348
# Test: Total time: 0:00:01 (0.0793 s / it)
# Averaged stats: class_error: 100.00  loss: 0.0268 (3.8050)  loss_ce: 0.0055 (0.8019)  loss_bbox: 0.0000 (0.0284)  loss_giou: 0.0000 (0.0492)  loss_ce_0: 0.0036 (0.5395)  loss_bbox_0: 0.0000 (0.0257)  loss_giou_0: 0.0000 (0.0453)  loss_ce_1: 0.0060 (0.7248)  loss_bbox_1: 0.0000 (0.0267)  loss_giou_1: 0.0000 (0.0460)  loss_ce_2: 0.0056 (0.7940)  loss_bbox_2: 0.0000 (0.0283)  loss_giou_2: 0.0000 (0.0494)  loss_ce_enc: 0.0009 (0.5599)  loss_bbox_enc: 0.0000 (0.0318)  loss_giou_enc: 0.0000 (0.0540)  loss_ce_unscaled: 0.0055 (0.8019)  class_error_unscaled: 100.0000 (83.6684)  loss_bbox_unscaled: 0.0000 (0.0057)  loss_giou_unscaled: 0.0000 (0.0246)  cardinality_error_unscaled: 115.5000 (122.2000)  loss_ce_0_unscaled: 0.0036 (0.5395)  loss_bbox_0_unscaled: 0.0000 (0.0051)  loss_giou_0_unscaled: 0.0000 (0.0227)  cardinality_error_0_unscaled: 198.0000 (203.2333)  loss_ce_1_unscaled: 0.0060 (0.7248)  loss_bbox_1_unscaled: 0.0000 (0.0053)  loss_giou_1_unscaled: 0.0000 (0.0230)  cardinality_error_1_unscaled: 227.0000 (224.4000)  loss_ce_2_unscaled: 0.0056 (0.7940)  loss_bbox_2_unscaled: 0.0000 (0.0057)  loss_giou_2_unscaled: 0.0000 (0.0247)  cardinality_error_2_unscaled: 183.0000 (182.6667)  loss_ce_enc_unscaled: 0.0009 (0.5599)  loss_bbox_enc_unscaled: 0.0000 (0.0064)  loss_giou_enc_unscaled: 0.0000 (0.0270)  cardinality_error_enc_unscaled: 278.0000 (272.6000)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.22503
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.30772
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.26382
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.70000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.56713
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.17888
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.10468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.61218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.76199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.70000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.72500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.81398
# Grad accum steps:  8
# Total batch size:  16
# LENGTH OF DATA LOADER: 10
# Epoch: [18]  [ 0/10]  eta: 0:00:19  lr: 0.000020  class_error: 100.00  loss: 0.2101 (0.2101)  loss_ce: 0.0620 (0.0620)  loss_bbox: 0.0000 (0.0000)  loss_giou: 0.0000 (0.0000)  loss_ce_0: 0.0256 (0.0256)  loss_bbox_0: 0.0000 (0.0000)  loss_giou_0: 0.0000 (0.0000)  loss_ce_1: 0.0548 (0.0548)  loss_bbox_1: 0.0000 (0.0000)  loss_giou_1: 0.0000 (0.0000)  loss_ce_2: 0.0562 (0.0562)  loss_bbox_2: 0.0000 (0.0000)  loss_giou_2: 0.0000 (0.0000)  loss_ce_enc: 0.0115 (0.0115)  loss_bbox_enc: 0.0000 (0.0000)  loss_giou_enc: 0.0000 (0.0000)  loss_ce_unscaled: 0.0620 (0.0620)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.0000 (0.0000)  loss_giou_unscaled: 0.0000 (0.0000)  cardinality_error_unscaled: 940.0000 (940.0000)  loss_ce_0_unscaled: 0.0256 (0.0256)  loss_bbox_0_unscaled: 0.0000 (0.0000)  loss_giou_0_unscaled: 0.0000 (0.0000)  cardinality_error_0_unscaled: 2198.5000 (2198.5000)  loss_ce_1_unscaled: 0.0548 (0.0548)  loss_bbox_1_unscaled: 0.0000 (0.0000)  loss_giou_1_unscaled: 0.0000 (0.0000)  cardinality_error_1_unscaled: 1954.5000 (1954.5000)  loss_ce_2_unscaled: 0.0562 (0.0562)  loss_bbox_2_unscaled: 0.0000 (0.0000)  loss_giou_2_unscaled: 0.0000 (0.0000)  cardinality_error_2_unscaled: 1579.5000 (1579.5000)  loss_ce_enc_unscaled: 0.0115 (0.0115)  loss_bbox_enc_unscaled: 0.0000 (0.0000)  loss_giou_enc_unscaled: 0.0000 (0.0000)  cardinality_error_enc_unscaled: 3274.5000 (3274.5000)  time: 1.9106  data: 0.6561  max mem: 3348
# Epoch: [18]  [ 9/10]  eta: 0:00:01  lr: 0.000020  class_error: 100.00  loss: 0.2817 (2.9297)  loss_ce: 0.0636 (0.4252)  loss_bbox: 0.0000 (0.0460)  loss_giou: 0.0000 (0.0556)  loss_ce_0: 0.0386 (0.4965)  loss_bbox_0: 0.0000 (0.0604)  loss_giou_0: 0.0000 (0.0625)  loss_ce_1: 0.0876 (0.4543)  loss_bbox_1: 0.0000 (0.0428)  loss_giou_1: 0.0000 (0.0535)  loss_ce_2: 0.0872 (0.4278)  loss_bbox_2: 0.0000 (0.0475)  loss_giou_2: 0.0000 (0.0568)  loss_ce_enc: 0.0267 (0.4958)  loss_bbox_enc: 0.0000 (0.1070)  loss_giou_enc: 0.0000 (0.0978)  loss_ce_unscaled: 0.0636 (0.4252)  class_error_unscaled: 0.0000 (50.0000)  loss_bbox_unscaled: 0.0000 (0.0092)  loss_giou_unscaled: 0.0000 (0.0278)  cardinality_error_unscaled: 1251.5000 (1328.7000)  loss_ce_0_unscaled: 0.0386 (0.4965)  loss_bbox_0_unscaled: 0.0000 (0.0121)  loss_giou_0_unscaled: 0.0000 (0.0312)  cardinality_error_0_unscaled: 2594.5000 (2481.8000)  loss_ce_1_unscaled: 0.0876 (0.4543)  loss_bbox_1_unscaled: 0.0000 (0.0086)  loss_giou_1_unscaled: 0.0000 (0.0268)  cardinality_error_1_unscaled: 2568.5000 (2595.6000)  loss_ce_2_unscaled: 0.0872 (0.4278)  loss_bbox_2_unscaled: 0.0000 (0.0095)  loss_giou_2_unscaled: 0.0000 (0.0284)  cardinality_error_2_unscaled: 2016.0000 (2151.2500)  loss_ce_enc_unscaled: 0.0267 (0.4958)  loss_bbox_enc_unscaled: 0.0000 (0.0214)  loss_giou_enc_unscaled: 0.0000 (0.0489)  cardinality_error_enc_unscaled: 3274.5000 (3191.5000)  time: 1.1868  data: 0.0804  max mem: 3348
# Epoch: [18] Total time: 0:00:11 (1.1930 s / it)
# Averaged stats: lr: 0.000020  class_error: 100.00  loss: 0.2817 (2.9297)  loss_ce: 0.0636 (0.4252)  loss_bbox: 0.0000 (0.0460)  loss_giou: 0.0000 (0.0556)  loss_ce_0: 0.0386 (0.4965)  loss_bbox_0: 0.0000 (0.0604)  loss_giou_0: 0.0000 (0.0625)  loss_ce_1: 0.0876 (0.4543)  loss_bbox_1: 0.0000 (0.0428)  loss_giou_1: 0.0000 (0.0535)  loss_ce_2: 0.0872 (0.4278)  loss_bbox_2: 0.0000 (0.0475)  loss_giou_2: 0.0000 (0.0568)  loss_ce_enc: 0.0267 (0.4958)  loss_bbox_enc: 0.0000 (0.1070)  loss_giou_enc: 0.0000 (0.0978)  loss_ce_unscaled: 0.0636 (0.4252)  class_error_unscaled: 0.0000 (50.0000)  loss_bbox_unscaled: 0.0000 (0.0092)  loss_giou_unscaled: 0.0000 (0.0278)  cardinality_error_unscaled: 1251.5000 (1328.7000)  loss_ce_0_unscaled: 0.0386 (0.4965)  loss_bbox_0_unscaled: 0.0000 (0.0121)  loss_giou_0_unscaled: 0.0000 (0.0312)  cardinality_error_0_unscaled: 2594.5000 (2481.8000)  loss_ce_1_unscaled: 0.0876 (0.4543)  loss_bbox_1_unscaled: 0.0000 (0.0086)  loss_giou_1_unscaled: 0.0000 (0.0268)  cardinality_error_1_unscaled: 2568.5000 (2595.6000)  loss_ce_2_unscaled: 0.0872 (0.4278)  loss_bbox_2_unscaled: 0.0000 (0.0095)  loss_giou_2_unscaled: 0.0000 (0.0284)  cardinality_error_2_unscaled: 2016.0000 (2151.2500)  loss_ce_enc_unscaled: 0.0267 (0.4958)  loss_bbox_enc_unscaled: 0.0000 (0.0214)  loss_giou_enc_unscaled: 0.0000 (0.0489)  cardinality_error_enc_unscaled: 3274.5000 (3191.5000)
# Test:  [ 0/15]  eta: 0:00:04  class_error: 0.00  loss: 8.0735 (8.0735)  loss_ce: 1.1719 (1.1719)  loss_bbox: 0.1182 (0.1182)  loss_giou: 0.3097 (0.3097)  loss_ce_0: 1.2422 (1.2422)  loss_bbox_0: 0.0980 (0.0980)  loss_giou_0: 0.2784 (0.2784)  loss_ce_1: 1.1953 (1.1953)  loss_bbox_1: 0.1029 (0.1029)  loss_giou_1: 0.2852 (0.2852)  loss_ce_2: 1.1797 (1.1797)  loss_bbox_2: 0.1193 (0.1193)  loss_giou_2: 0.3122 (0.3122)  loss_ce_enc: 1.2344 (1.2344)  loss_bbox_enc: 0.1150 (0.1150)  loss_giou_enc: 0.3111 (0.3111)  loss_ce_unscaled: 1.1719 (1.1719)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0236 (0.0236)  loss_giou_unscaled: 0.1549 (0.1549)  cardinality_error_unscaled: 128.5000 (128.5000)  loss_ce_0_unscaled: 1.2422 (1.2422)  loss_bbox_0_unscaled: 0.0196 (0.0196)  loss_giou_0_unscaled: 0.1392 (0.1392)  cardinality_error_0_unscaled: 184.5000 (184.5000)  loss_ce_1_unscaled: 1.1953 (1.1953)  loss_bbox_1_unscaled: 0.0206 (0.0206)  loss_giou_1_unscaled: 0.1426 (0.1426)  cardinality_error_1_unscaled: 181.5000 (181.5000)  loss_ce_2_unscaled: 1.1797 (1.1797)  loss_bbox_2_unscaled: 0.0239 (0.0239)  loss_giou_2_unscaled: 0.1561 (0.1561)  cardinality_error_2_unscaled: 158.0000 (158.0000)  loss_ce_enc_unscaled: 1.2344 (1.2344)  loss_bbox_enc_unscaled: 0.0230 (0.0230)  loss_giou_enc_unscaled: 0.1555 (0.1555)  cardinality_error_enc_unscaled: 200.0000 (200.0000)  time: 0.3009  data: 0.2100  max mem: 3348
# Test:  [10/15]  eta: 0:00:00  class_error: 100.00  loss: 7.4434 (7.0653)  loss_ce: 1.1719 (1.5715)  loss_bbox: 0.0000 (0.0384)  loss_giou: 0.0000 (0.0670)  loss_ce_0: 1.2422 (1.0817)  loss_bbox_0: 0.0000 (0.0363)  loss_giou_0: 0.0000 (0.0624)  loss_ce_1: 1.1953 (1.3524)  loss_bbox_1: 0.0000 (0.0371)  loss_giou_1: 0.0000 (0.0643)  loss_ce_2: 1.1797 (1.5191)  loss_bbox_2: 0.0000 (0.0381)  loss_giou_2: 0.0000 (0.0669)  loss_ce_enc: 0.4121 (1.0028)  loss_bbox_enc: 0.0000 (0.0510)  loss_giou_enc: 0.0000 (0.0763)  loss_ce_unscaled: 1.1719 (1.5715)  class_error_unscaled: 100.0000 (76.2987)  loss_bbox_unscaled: 0.0000 (0.0077)  loss_giou_unscaled: 0.0000 (0.0335)  cardinality_error_unscaled: 114.5000 (120.7273)  loss_ce_0_unscaled: 1.2422 (1.0817)  loss_bbox_0_unscaled: 0.0000 (0.0073)  loss_giou_0_unscaled: 0.0000 (0.0312)  cardinality_error_0_unscaled: 184.5000 (188.5000)  loss_ce_1_unscaled: 1.1953 (1.3524)  loss_bbox_1_unscaled: 0.0000 (0.0074)  loss_giou_1_unscaled: 0.0000 (0.0321)  cardinality_error_1_unscaled: 213.0000 (209.9091)  loss_ce_2_unscaled: 1.1797 (1.5191)  loss_bbox_2_unscaled: 0.0000 (0.0076)  loss_giou_2_unscaled: 0.0000 (0.0335)  cardinality_error_2_unscaled: 167.5000 (172.0455)  loss_ce_enc_unscaled: 0.4121 (1.0028)  loss_bbox_enc_unscaled: 0.0000 (0.0102)  loss_giou_enc_unscaled: 0.0000 (0.0381)  cardinality_error_enc_unscaled: 256.5000 (256.5909)  time: 0.0679  data: 0.0264  max mem: 3348
# Test:  [14/15]  eta: 0:00:00  class_error: 100.00  loss: 0.7469 (5.2590)  loss_ce: 0.2139 (1.1673)  loss_bbox: 0.0000 (0.0281)  loss_giou: 0.0000 (0.0491)  loss_ce_0: 0.1484 (0.8128)  loss_bbox_0: 0.0000 (0.0266)  loss_giou_0: 0.0000 (0.0457)  loss_ce_1: 0.1206 (1.0036)  loss_bbox_1: 0.0000 (0.0272)  loss_giou_1: 0.0000 (0.0471)  loss_ce_2: 0.2637 (1.1325)  loss_bbox_2: 0.0000 (0.0280)  loss_giou_2: 0.0000 (0.0491)  loss_ce_enc: 0.0471 (0.7484)  loss_bbox_enc: 0.0000 (0.0374)  loss_giou_enc: 0.0000 (0.0559)  loss_ce_unscaled: 0.2139 (1.1673)  class_error_unscaled: 100.0000 (82.6190)  loss_bbox_unscaled: 0.0000 (0.0056)  loss_giou_unscaled: 0.0000 (0.0246)  cardinality_error_unscaled: 114.5000 (117.7000)  loss_ce_0_unscaled: 0.1484 (0.8128)  loss_bbox_0_unscaled: 0.0000 (0.0053)  loss_giou_0_unscaled: 0.0000 (0.0229)  cardinality_error_0_unscaled: 184.5000 (184.1333)  loss_ce_1_unscaled: 0.1206 (1.0036)  loss_bbox_1_unscaled: 0.0000 (0.0054)  loss_giou_1_unscaled: 0.0000 (0.0236)  cardinality_error_1_unscaled: 213.0000 (206.9667)  loss_ce_2_unscaled: 0.2637 (1.1325)  loss_bbox_2_unscaled: 0.0000 (0.0056)  loss_giou_2_unscaled: 0.0000 (0.0245)  cardinality_error_2_unscaled: 167.5000 (168.2000)  loss_ce_enc_unscaled: 0.0471 (0.7484)  loss_bbox_enc_unscaled: 0.0000 (0.0075)  loss_giou_enc_unscaled: 0.0000 (0.0280)  cardinality_error_enc_unscaled: 273.5000 (263.5333)  time: 0.0587  data: 0.0206  max mem: 3348
# Test: Total time: 0:00:00 (0.0626 s / it)
# Averaged stats: class_error: 100.00  loss: 0.7469 (5.2590)  loss_ce: 0.2139 (1.1673)  loss_bbox: 0.0000 (0.0281)  loss_giou: 0.0000 (0.0491)  loss_ce_0: 0.1484 (0.8128)  loss_bbox_0: 0.0000 (0.0266)  loss_giou_0: 0.0000 (0.0457)  loss_ce_1: 0.1206 (1.0036)  loss_bbox_1: 0.0000 (0.0272)  loss_giou_1: 0.0000 (0.0471)  loss_ce_2: 0.2637 (1.1325)  loss_bbox_2: 0.0000 (0.0280)  loss_giou_2: 0.0000 (0.0491)  loss_ce_enc: 0.0471 (0.7484)  loss_bbox_enc: 0.0000 (0.0374)  loss_giou_enc: 0.0000 (0.0559)  loss_ce_unscaled: 0.2139 (1.1673)  class_error_unscaled: 100.0000 (82.6190)  loss_bbox_unscaled: 0.0000 (0.0056)  loss_giou_unscaled: 0.0000 (0.0246)  cardinality_error_unscaled: 114.5000 (117.7000)  loss_ce_0_unscaled: 0.1484 (0.8128)  loss_bbox_0_unscaled: 0.0000 (0.0053)  loss_giou_0_unscaled: 0.0000 (0.0229)  cardinality_error_0_unscaled: 184.5000 (184.1333)  loss_ce_1_unscaled: 0.1206 (1.0036)  loss_bbox_1_unscaled: 0.0000 (0.0054)  loss_giou_1_unscaled: 0.0000 (0.0236)  cardinality_error_1_unscaled: 213.0000 (206.9667)  loss_ce_2_unscaled: 0.2637 (1.1325)  loss_bbox_2_unscaled: 0.0000 (0.0056)  loss_giou_2_unscaled: 0.0000 (0.0245)  cardinality_error_2_unscaled: 167.5000 (168.2000)  loss_ce_enc_unscaled: 0.0471 (0.7484)  loss_bbox_enc_unscaled: 0.0000 (0.0075)  loss_giou_enc_unscaled: 0.0000 (0.0280)  cardinality_error_enc_unscaled: 273.5000 (263.5333)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.28516
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.38000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.33959
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.72500
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.59721
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.24915
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.13762
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.64981
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.77729
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.80000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.76364
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.81118
# Exception ignored in: <function _releaseLock at 0x151aae0a8540>
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 243, in _releaseLock
#     def _releaseLock():
#
# KeyboardInterrupt:
